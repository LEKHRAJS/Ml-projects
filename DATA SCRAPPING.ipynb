# %% [markdown]
# # SAVING THE DETAILS IN VARIBALES

# %%
import pandas as pd
import ast

# %%
df = pd.read_csv("C:\\Users\\faiza\\Downloads\\MACHINE LEARNING MODELS\\WEB DEV SENIORS\\data.csv")
df
# Out:
#                                      CompanyName  \
# 0                Bira 91 Limited Release Taproom
# 1             Ataura Coworking Space Koramangala
# 2                 Novel Office Salarpuria Triton
# 3                            Incubex Koramangala
# 4                              BHIVE Koramangala
# 5                      91springboard Koramangala
# 6                      91springboard Koramangala
# 7                        One Co.work Koramangala
# 8                         UrbanVault Koramangala
# 9                        WeWork Prestige Atlanta
# 10                  IndiQube Octagon Koramangala
# 11  InstaOffice (permanently Closed) Koramangala
# 12     WorkHome Koramangala (Temporarily closed)
# 13                                ClayWorks  CBD
# 14                Zillion Biz Center Koramangala
# 15                        Vibranium  Koramangala
# 16                        Solo Cubes Koramangala
# 17                   Mayfair Coworks Koramangala
# ...

# %%
# checking  for the null value
df.isnull().sum()
# Out:
# CompanyName       0
# Location          0
# Capacity          0
# AboutCompany      0
# MembershipPlan    0
# Services          0
# Amenities         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CompanyName', 'Location', 'Capacity', 'AboutCompany', 'MembershipPlan',
#        'Services', 'Amenities'],
#       dtype='object')

# %%
# dropping the unnamed column as we dont need it 
#df.rename({"Unnamed: 7":"a"}, axis="columns", inplace=True)
# Then, drop the column as usual.
#df.drop(["a"], axis=1, inplace=True)

# %%
df
# Out:
#                                      CompanyName  \
# 0                Bira 91 Limited Release Taproom
# 1             Ataura Coworking Space Koramangala
# 2                 Novel Office Salarpuria Triton
# 3                            Incubex Koramangala
# 4                              BHIVE Koramangala
# 5                      91springboard Koramangala
# 6                      91springboard Koramangala
# 7                        One Co.work Koramangala
# 8                         UrbanVault Koramangala
# 9                        WeWork Prestige Atlanta
# 10                  IndiQube Octagon Koramangala
# 11  InstaOffice (permanently Closed) Koramangala
# 12     WorkHome Koramangala (Temporarily closed)
# 13                                ClayWorks  CBD
# 14                Zillion Biz Center Koramangala
# 15                        Vibranium  Koramangala
# 16                        Solo Cubes Koramangala
# 17                   Mayfair Coworks Koramangala
# ...

# %% [markdown]
# # Pre Processing

# %%
# removing the \n from the data and brining it into standard form
df = df.replace('\n','', regex=True)

# %%
df
# Out:
#                                      CompanyName  \
# 0                Bira 91 Limited Release Taproom
# 1             Ataura Coworking Space Koramangala
# 2                 Novel Office Salarpuria Triton
# 3                            Incubex Koramangala
# 4                              BHIVE Koramangala
# 5                      91springboard Koramangala
# 6                      91springboard Koramangala
# 7                        One Co.work Koramangala
# 8                         UrbanVault Koramangala
# 9                        WeWork Prestige Atlanta
# 10                  IndiQube Octagon Koramangala
# 11  InstaOffice (permanently Closed) Koramangala
# 12     WorkHome Koramangala (Temporarily closed)
# 13                                ClayWorks  CBD
# 14                Zillion Biz Center Koramangala
# 15                        Vibranium  Koramangala
# 16                        Solo Cubes Koramangala
# 17                   Mayfair Coworks Koramangala
# ...

# %%
# storing values in variable 
company_name = df.iloc[0:20]['CompanyName']
Location = df.iloc[0:20]['Location']
Capacity = df.iloc[0:20]['Capacity']
AbtCompany = df.iloc[0:20]['AboutCompany']
MembPlan = df.iloc[0:20]['MembershipPlan']
Services = df.iloc[0:20]['Services']
Amenities = df.iloc[0:20]['Amenities']

# %%
company_name
# Out:
# 0                  Bira 91 Limited Release Taproom
# 1               Ataura Coworking Space Koramangala
# 2                   Novel Office Salarpuria Triton
# 3                              Incubex Koramangala
# 4                                BHIVE Koramangala
# 5                        91springboard Koramangala
# 6                        91springboard Koramangala
# 7                          One Co.work Koramangala
# 8                           UrbanVault Koramangala
# 9                          WeWork Prestige Atlanta
# 10                    IndiQube Octagon Koramangala
# 11    InstaOffice (permanently Closed) Koramangala
# 12       WorkHome Koramangala (Temporarily closed)
# 13                                  ClayWorks  CBD
# 14                  Zillion Biz Center Koramangala
# 15                          Vibranium  Koramangala
# 16                          Solo Cubes Koramangala
# 17                     Mayfair Coworks Koramangala
# ...

# %%
Amenities
# Out:
# 0     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 1     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 2     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 3     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 4     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 5     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 6     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 7     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 8     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 9     AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 10    AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 11    AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 12    AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 13    AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 14    AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 15    AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# 16    AmenitiesWIFI/InternetComfy WorkstationsMeetin...
# ...

# %%
Services
# Out:
# 0     Enterprise ServicesOffice SuiteOffice space fo...
# 1     Enterprise ServicesOffice SuiteOffice space fo...
# 2     Enterprise ServicesOffice SuiteOffice space fo...
# 3     Enterprise ServicesOffice SuiteOffice space fo...
# 4     Enterprise ServicesOffice SuiteOffice space fo...
# 5     Enterprise ServicesOffice SuiteOffice space fo...
# 6     Enterprise ServicesOffice SuiteOffice space fo...
# 7     Enterprise ServicesOffice SuiteOffice space fo...
# 8     Enterprise ServicesOffice SuiteOffice space fo...
# 9     Enterprise ServicesOffice SuiteOffice space fo...
# 10    Enterprise ServicesOffice SuiteOffice space fo...
# 11    Enterprise ServicesOffice SuiteOffice space fo...
# 12    Enterprise ServicesOffice SuiteOffice space fo...
# 13    Enterprise ServicesOffice SuiteOffice space fo...
# 14    Enterprise ServicesOffice SuiteOffice space fo...
# 15    Enterprise ServicesOffice SuiteOffice space fo...
# 16    Enterprise ServicesOffice SuiteOffice space fo...
# ...
